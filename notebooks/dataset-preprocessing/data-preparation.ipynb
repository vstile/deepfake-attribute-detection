# %%
# Loading the dataset from the specified paths.
# Preprocessing frames to extract faces.

# %%
# # Unzip
# !unzip /content/videos.zip

# %%
# Paths to REAL and FAKE videos
REAL_VIDEOS_PATH = "/Users/vittoriostile/Developer/youtube_c40/videos"
FAKE_VIDEOS_PATHS = [
#    "/Volumes/Maxtor 4Tb/FaceForensics++/manipulated_sequences/Deepfakes/c40/videos",
#   "/Volumes/Maxtor 4Tb/FaceForensics++/manipulated_sequences/Face2Face/c40/videos",
#    "/Volumes/Maxtor 4Tb/FaceForensics++/manipulated_sequences/FaceShifter/c40/videos",
    "/Volumes/Maxtor 4Tb/FaceForensics++/manipulated_sequences/FaceSwap/c40/videos",
#    "/Volumes/Maxtor 4Tb/FaceForensics++/manipulated_sequences/NeuralTextures/c40/videos",
]

LABELS = {"REAL": 0, "FAKE": 1}

# %%
# from google.colab import files

# %%
import os
import cv2
import numpy as np
import zipfile

# %%
def extract_faces_from_video(video_path, label, cascade_classifier, frame_skip=1):
    """
    Estrae i volti da un video e li salva in una cartella
    e crea un file zip per i frame e i volti.

    Args:
        video_path: Percorso del video.
        label: Etichetta del video (REAL o FAKE).
        cascade_classifier: Classificatore di volti.
        frame_skip: Numero di frame da saltare tra un'elaborazione e l'altra.
    """
    faces = []
    labels = []

    # Apre il video
    cap = cv2.VideoCapture(video_path)

    # Crea la cartella di output per i volti (relativa alla directory del video)
    video_dir = os.path.dirname(video_path)
    faces_output_dir = os.path.join(os.path.dirname(video_dir), "faces")  # Directory per faces
    os.makedirs(faces_output_dir, exist_ok=True)

    # Crea la cartella di output per i frame (relativa alla directory del video)
    frames_output_dir = os.path.join(os.path.dirname(video_dir), "frames")  # Directory per frames
    os.makedirs(frames_output_dir, exist_ok=True)

    # Get the video file name without extension
    video_file_name = os.path.splitext(os.path.basename(video_path))[0]

    frame_count = 0  # Inizializza frame_count a 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Salva il frame nella cartella frames
        frame_output_path = os.path.join(frames_output_dir, f"{video_file_name}_{frame_count:03d}.jpeg")
        cv2.imwrite(frame_output_path, frame)

        if frame_count % frame_skip == 0:
            # Resize frame for faster processing (optional)
            frame = cv2.resize(frame, (640, 480))

            # Convert to grayscale for Haar Cascades
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

            # Detect faces using Haar Cascades
            faces_detected = cascade_classifier.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

            # Save detected faces (with frame number and face index)
            for i, (x, y, w, h) in enumerate(faces_detected):
                face = frame[y:y + h, x:x + w]
                face_resized = cv2.resize(face, (224, 224))
                face_output_path = os.path.join(faces_output_dir, f"{video_file_name}_{frame_count:03d}_face{i}.jpeg")
                cv2.imwrite(face_output_path, face_resized)
                faces.append(face_resized)
                labels.append(label)
        frame_count += 1

    # Rilascia il video
    cap.release()

    # # --- Inizio del codice per la creazione dello zip ---
    # print("Creazione dello zip dei frame e dei volti...")

    # # Nome del file zip (basato sul nome del video)
    # video_file_name = os.path.splitext(os.path.basename(video_path))[0]
    # zip_file_name = f"{video_file_name}_frames_faces.zip"

    # # Crea il file zip
    # with zipfile.ZipFile(zip_file_name, 'w') as zipf:
    #     # Aggiungi i frame allo zip
    #     for frame_file in os.listdir(frames_output_dir):
    #         frame_path = os.path.join(frames_output_dir, frame_file)
    #         zipf.write(frame_path, arcname=os.path.join('frames', frame_file))

    #     # Aggiungi i volti allo zip
    #     for face_file in os.listdir(faces_output_dir):
    #         face_path = os.path.join(faces_output_dir, face_file)
    #         zipf.write(face_path, arcname=os.path.join('faces', face_file))

    # print(f"Zip creato: {zip_file_name}")
    # --- Fine del codice per la creazione dello zip ---

    # Scarica lo zip in locale
    #files.download(zip_file_name)
    #print(f"Zip {zip_file_name} scaricato in locale.")
    # --- Fine del codice per la creazione e il download dello zip ---

    return np.array(faces), np.array(labels)

# %%
def load_subset_dataset(real_path, fake_paths, cascade_path):  # Prende all videos, ho rimosso un max_videos parameter usato in precedenza
    face_cascade = cv2.CascadeClassifier(cascade_path)
    faces = []
    labels = []

    # Load all REAL videos
    for video in os.listdir(real_path):  # Removed [:max_videos]
        video_path = os.path.join(real_path, video)
        face_frames, face_labels = extract_faces_from_video(video_path, LABELS["REAL"], face_cascade)
        faces.extend(face_frames)
        labels.extend(face_labels)
        # print(f"Processed REAL video: {video}, extracted {len(face_frames)} faces")  # Print per video REAL

    # Load all FAKE videos
    for fake_path in fake_paths:
        for video in os.listdir(fake_path):  # Removed [:max_videos]
            video_path = os.path.join(fake_path, video)
            face_frames, face_labels = extract_faces_from_video(video_path, LABELS["FAKE"], face_cascade)
            faces.extend(face_frames)
            labels.extend(face_labels)
            # print(f"Processed FAKE video: {video}, extracted {len(face_frames)} faces")  # Print per video FAKE

    return np.array(faces), np.array(labels)

# %%
def process_videos_in_batches(real_path, fake_paths, cascade_path, batch_size=50, start_batch=0, start_folder=0, process_real=True, process_fake=True):
    """
    Elabora i video in batch, consentendo di specificare il batch e la cartella di partenza.

    Args:
        real_path: Percorso della cartella dei video reali.
        fake_paths: Lista di percorsi delle cartelle dei video falsi.
        cascade_path: Percorso del classificatore a cascata.
        batch_size: Dimensione del batch di video da elaborare.
        start_batch: Batch da cui iniziare l'elaborazione (0-based).
        start_folder: Indice della cartella da cui iniziare l'elaborazione (0 per REAL, 1-5 per FAKE).
        process_real: Booleano per indicare se elaborare i video reali.
        process_fake: Booleano per indicare se elaborare i video falsi.
    """
    face_cascade = cv2.CascadeClassifier(cascade_path)
    faces = []
    labels = []
    current_batch = start_batch

    def process_folder(folder_path, label, folder_name):
        nonlocal current_batch

        # Carica lo stato dal file, se presente
        try:
            with open("stato_elaborazione.txt", "r") as f:
                current_batch, file_index = map(int, f.read().split(","))
                print(f"Ripresa dell'elaborazione dal batch {current_batch}, file {file_index}")
        except FileNotFoundError:
            file_index = 0  # Inizializza file_index se il file di stato non esiste

        # Ciclo sui batch, 20 batch per 1000 video
        for batch_index in range(start_batch, 20):  # Ciclo sui batch, 20 batch per 1000 video
            print(f"Elaborazione batch {batch_index} in cartella: {folder_name}")  # Mostra il batch effettivo (0-19)

            # Ottieni gli ultimi tre livelli del percorso della cartella
            folder_levels = folder_path.split(os.path.sep)[-3:]
            folder_path_display = os.path.sep.join(folder_levels)
            print(f"Percorso cartella: {folder_path_display}")

            # Print per i file presenti nella cartella
            print(f"File nella cartella: {os.listdir(folder_path)}")

            # Calcola l'inizio del batch corrente
            batch_start = batch_index * batch_size

            # Ottieni tutti i file nella cartella e ordinali
            all_files = sorted(os.listdir(folder_path))

            # Filtra i file per il batch corrente, considerando il formato del nome
            batch_files = [
                f for f in all_files
                if f.endswith(".mp4") and (
                    (folder_name == "REAL" and int(f.split(".")[0]) in range(batch_start, min(batch_start + batch_size, 1000))) or
                    (folder_name != "REAL" and int(f.split("_")[0]) in range(batch_start, min(batch_start + batch_size, 1000)))
                )
            ]

            # Stampa i file selezionati per il batch
            print(f"File selezionati per il batch {current_batch}: {batch_files}")

            # Elabora i file del batch
            for i, video_file in enumerate(batch_files):  # Inserisci qui enumerate
                # Salta i file già elaborati se si riprende l'elaborazione
                if i < file_index:
                    continue

                video_path = os.path.join(folder_path, video_file)
                face_frames, face_labels = extract_faces_from_video(video_path, label, face_cascade)
                faces.extend(face_frames)
                labels.extend(face_labels)
                print(f"Elaborato video: {video_file}, estratti {len(face_frames)} volti")

                # Salva lo stato dopo aver elaborato ogni file
                file_index = i + 1  # Aggiorna l'indice del file
                with open("stato_elaborazione.txt", "w") as f:
                    f.write(f"{current_batch},{file_index}")

            # Resetta l'indice del file all'inizio di ogni nuovo batch
            file_index = 0

            current_batch += 1

    if process_real:
        process_folder(real_path, LABELS["REAL"], "REAL")

    if process_fake:
        for folder_index, fake_path in enumerate(fake_paths, 1):  # Inizia da 1 per le cartelle fake
            if folder_index >= start_folder:
                # Resetta current_batch a start_batch quando si inizia una nuova cartella
                current_batch = start_batch
                folder_name = os.path.basename(fake_path)  # Ottiene il nome della cartella
                process_folder(fake_path, LABELS["FAKE"], folder_name)  # Passa il nome della cartella

    return np.array(faces), np.array(labels)

# %%
# Esempio di utilizzo:
# Inizia dall'elaborazione dei video fake, dal batch 0 (video 100-149)
cascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
faces, labels = process_videos_in_batches(REAL_VIDEOS_PATH, FAKE_VIDEOS_PATHS, cascade_path, start_batch=14, start_folder=0, process_real=False, process_fake=True)
# Out:
# Ripresa dell'elaborazione dal batch 14, file 0
# Elaborazione batch 14 in cartella: videos
# Percorso cartella: FaceSwap/c40/videos
# File nella cartella: ['475_265.mp4', '366_473.mp4', '944_032.mp4', '135_880.mp4', '002_006.mp4', '078_955.mp4', '051_332.mp4', '193_030.mp4', '068_028.mp4', '654_648.mp4', '151_225.mp4', '460_678.mp4', '173_171.mp4', '139_130.mp4', '030_193.mp4', '862_047.mp4', '762_832.mp4', '268_269.mp4', '503_756.mp4', '213_083.mp4', '748_355.mp4', '751_752.mp4', '666_656.mp4', '892_112.mp4', '734_699.mp4', '876_891.mp4', '620_619.mp4', '391_406.mp4', '343_363.mp4', '448_361.mp4', '750_743.mp4', '402_453.mp4', '304_300.mp4', '765_867.mp4', '817_827.mp4', '228_289.mp4', '499_539.mp4', '155_576.mp4', '917_924.mp4', '380_358.mp4', '628_568.mp4', '777_745.mp4', '219_220.mp4', '603_575.mp4', '982_004.mp4', '939_115.mp4', '408_424.mp4', '107_109.mp4', '461_250.mp4', '140_143.mp4', '627_658.mp4', '185_276.mp4', '991_064.mp4', '759_755.mp4', '902_901.mp4', '592_500.mp4', '430_459.mp4', '872_873.mp4', '441_439.mp4', '924_917.mp4', '112_892.mp4', '824_419.mp4', '694_767.mp4', '708_772.mp4', '890_837.mp4', '852_834.mp4', '595_597.mp4', '360_437.mp4', '207_908.mp4', '017_803.mp4', '575_603.mp4', '075_977.mp4', '443_514.mp4', '848_894.mp4', '241_210.mp4', '578_636.mp4', '158_379.mp4', '116_091.mp4', '706_479.mp4', '476_400.mp4', '755_759.mp4', '615_687.mp4', '273_807.mp4', '236_237.mp4', '440_364.mp4', '346_351.mp4', '272_396.mp4', '466_428.mp4', '003_000.mp4', '294_292.mp4', '129_127.mp4', '531_549.mp4', '828_830.mp4', '357_432.mp4', '958_956.mp4', '165_137.mp4', '096_101.mp4', '359_317.mp4', '879_963.mp4', '403_497.mp4', '435_456.mp4', '667_446.mp4', '285_136.mp4', '875_979.mp4', '120_118.mp4', '217_117.mp4', '570_624.mp4', '674_744.mp4', '252_266.mp4', '624_570.mp4', '952_882.mp4', '264_271.mp4', '378_368.mp4', '941_940.mp4', '381_376.mp4', '322_315.mp4', '866_878.mp4', '337_522.mp4', '037_072.mp4', '740_796.mp4', '404_429.mp4', '979_875.mp4', '342_416.mp4', '137_165.mp4', '260_331.mp4', '682_669.mp4', '565_589.mp4', '710_788.mp4', '504_502.mp4', '786_819.mp4', '629_618.mp4', '561_998.mp4', '589_565.mp4', '471_455.mp4', '675_608.mp4', '401_395.mp4', '261_254.mp4', '829_808.mp4', '729_727.mp4', '494_445.mp4', '020_344.mp4', '131_518.mp4', '470_468.mp4', '717_684.mp4', '591_605.mp4', '105_180.mp4', '330_162.mp4', '712_716.mp4', '059_050.mp4', '645_688.mp4', '560_557.mp4', '287_426.mp4', '093_121.mp4', '121_093.mp4', '122_144.mp4', '648_654.mp4', '871_814.mp4', '877_886.mp4', '509_525.mp4', '563_537.mp4', '940_941.mp4', '535_587.mp4', '076_079.mp4', '630_623.mp4', '368_378.mp4', '227_169.mp4', '280_249.mp4', '409_382.mp4', '967_984.mp4', '739_865.mp4', '231_663.mp4', '469_481.mp4', '673_728.mp4', '176_190.mp4', '318_334.mp4', '992_980.mp4', '425_485.mp4', '527_454.mp4', '756_503.mp4', '543_559.mp4', '754_758.mp4', '237_236.mp4', '282_238.mp4', '518_131.mp4', '312_021.mp4', '622_647.mp4', '270_297.mp4', '959_957.mp4', '631_551.mp4', '906_847.mp4', '149_152.mp4', '935_733.mp4', '186_170.mp4', '392_339.mp4', '608_675.mp4', '758_754.mp4', '745_777.mp4', '873_872.mp4', '954_976.mp4', '275_887.mp4', '600_505.mp4', '427_637.mp4', '102_114.mp4', '062_066.mp4', '774_735.mp4', '305_513.mp4', '281_474.mp4', '265_475.mp4', '950_836.mp4', '483_370.mp4', '885_802.mp4', '150_153.mp4', '464_463.mp4', '501_326.mp4', '587_535.mp4', '793_768.mp4', '976_954.mp4', '374_407.mp4', '820_818.mp4', '931_936.mp4', '016_209.mp4', '951_947.mp4', '804_738.mp4', '961_069.mp4', '269_268.mp4', '056_996.mp4', '544_532.mp4', '868_949.mp4', '324_356.mp4', '251_375.mp4', '782_787.mp4', '546_621.mp4', '685_613.mp4', '233_995.mp4', '323_302.mp4', '428_466.mp4', '869_780.mp4', '524_580.mp4', '747_854.mp4', '973_970.mp4', '859_843.mp4', '886_877.mp4', '033_097.mp4', '571_746.mp4', '054_071.mp4', '621_546.mp4', '642_635.mp4', '317_359.mp4', '245_157.mp4', '307_365.mp4', '024_073.mp4', '775_742.mp4', '053_095.mp4', '399_488.mp4', '138_142.mp4', '878_866.mp4', '678_460.mp4', '210_241.mp4', '100_077.mp4', '638_640.mp4', '184_205.mp4', '234_187.mp4', '148_133.mp4', '752_751.mp4', '042_084.mp4', '00 ...
# File selezionati per il batch 14: ['700_813.mp4', '701_579.mp4', '702_612.mp4', '703_604.mp4', '704_723.mp4', '705_707.mp4', '706_479.mp4', '707_705.mp4', '708_772.mp4', '709_390.mp4', '710_788.mp4', '711_681.mp4', '712_716.mp4', '713_726.mp4', '714_842.mp4', '715_721.mp4', '716_712.mp4', '717_684.mp4', '718_972.mp4', '719_737.mp4', '720_672.mp4', '721_715.mp4', '722_458.mp4', '723_704.mp4', '724_725.mp4', '725_724.mp4', '726_713.mp4', '727_729.mp4', '728_673.mp4', '729_727.mp4', '730_815.mp4', '731_741.mp4', '732_691.mp4', '733_935.mp4', '734_699.mp4', '735_774.mp4', '736_785.mp4', '737_719.mp4', '738_804.mp4', '739_865.mp4', '740_796.mp4', '741_731.mp4', '742_775.mp4', '743_750.mp4', '744_674.mp4', '745_777.mp4', '746_571.mp4', '747_854.mp4', '748_355.mp4', '749_659.mp4']
# Elaborato video: 700_813.mp4, estratti 306 volti
# Elaborato video: 701_579.mp4, estratti 400 volti
# Elaborato video: 702_612.mp4, estratti 406 volti
# Elaborato video: 703_604.mp4, estratti 65 volti
# Elaborato video: 704_723.mp4, estratti 460 volti
# Elaborato video: 705_707.mp4, estratti 723 volti
# Elaborato video: 706_479.mp4, estratti 327 volti
# Elaborato video: 707_705.mp4, estratti 477 volti
# Elaborato video: 708_772.mp4, estratti 343 volti
# Elaborato video: 709_390.mp4, estratti 329 volti
# Elaborato video: 710_788.mp4, estratti 378 volti
# Elaborato video: 711_681.mp4, estratti 292 volti
# Elaborato video: 712_716.mp4, estratti 565 volti
# Elaborato video: 713_726.mp4, estratti 390 volti
# Elaborato video: 714_842.mp4, estratti 449 volti
# Elaborato video: 715_721.mp4, estratti 581 volti
# Elaborato video: 716_712.mp4, estratti 627 volti
# Elaborato video: 717_684.mp4, estratti 374 volti
# Elaborato video: 718_972.mp4, estratti 340 volti
# Elaborato video: 719_737.mp4, estratti 370 volti
# Elaborato video: 720_672.mp4, estratti 509 volti
# Elaborato video: 721_715.mp4, estratti 576 volti
# Elaborato video: 722_458.mp4, estratti 138 volti
# Elaborato video: 723_704.mp4, estratti 386 volti
# Elaborato video: 724_725.mp4, estratti 857 volti
# Elaborato video: 725_724.mp4, estratti 602 volti
# Elaborato video: 726_713.mp4, estratti 410 volti
# Elaborato video: 727_729.mp4, estratti 569 volti
# Elaborato video: 728_673.mp4, estratti 790 volti
# Elaborato video: 729_727.mp4, estratti 545 volti
# Elaborato video: 730_815.mp4, estratti 452 volti
# Elaborato video: 731_741.mp4, estratti 620 volti
# Elaborato video: 732_691.mp4, estratti 360 volti
# Elaborato video: 733_935.mp4, estratti 519 volti
# Elaborato video: 734_699.mp4, estratti 525 volti
# Elaborato video: 735_774.mp4, estratti 394 volti
# Elaborato video: 736_785.mp4, estratti 847 volti
# Elaborato video: 737_719.mp4, estratti 384 volti
# Elaborato video: 738_804.mp4, estratti 271 volti
# Elaborato video: 739_865.mp4, estratti 312 volti
# Elaborato video: 740_796.mp4, estratti 284 volti
# Elaborato video: 741_731.mp4, estratti 370 volti
# Elaborato video: 742_775.mp4, estratti 559 volti
# Elaborato video: 743_750.mp4, estratti 377 volti
# Elaborato video: 744_674.mp4, estratti 291 volti
# Elaborato video: 745_777.mp4, estratti 325 volti
# Elaborato video: 746_571.mp4, estratti 493 volti
# Elaborato video: 747_854.mp4, estratti 288 volti
# Elaborato video: 748_355.mp4, estratti 355 volti
# Elaborato video: 749_659.mp4, estratti 708 volti
# Elaborazione batch 15 in cartella: videos
# Percorso cartella: FaceSwap/c40/videos
# File nella cartella: ['475_265.mp4', '366_473.mp4', '944_032.mp4', '135_880.mp4', '002_006.mp4', '078_955.mp4', '051_332.mp4', '193_030.mp4', '068_028.mp4', '654_648.mp4', '151_225.mp4', '460_678.mp4', '173_171.mp4', '139_130.mp4', '030_193.mp4', '862_047.mp4', '762_832.mp4', '268_269.mp4', '503_756.mp4', '213_083.mp4', '748_355.mp4', '751_752.mp4', '666_656.mp4', '892_112.mp4', '734_699.mp4', '876_891.mp4', '620_619.mp4', '391_406.mp4', '343_363.mp4', '448_361.mp4', '750_743.mp4', '402_453.mp4', '304_300.mp4', '765_867.mp4', '817_827.mp4', '228_289.mp4', '499_539.mp4', '155_576.mp4', '917_924.mp4', '380_358.mp4', '628_568.mp4', '777_745.mp4', '219_220.mp4', '603_575.mp4', '982_004.mp4', '939_115.mp4', '408_424.mp4', '107_109.mp4', '461_250.mp4', '140_143.mp4', '627_658.mp4', '185_276.mp4', '991_064.mp4', '759_755.mp4', '902_901.mp4', '592_500.mp4', '430_459.mp4', '872_873.mp4', '441_439.mp4', '924_917.mp4', '112_892.mp4', '824_419.mp4', '694_767.mp4', '708_772.mp4', '890_837.mp4', '852_834.mp4', '595_597.mp4', '360_437.mp4', '207_908.mp4', '017_803.mp4', '575_603.mp4', '075_977.mp4', '443_514.mp4', '848_894.mp4', '241_210.mp4', '578_636.mp4', '158_379.mp4', '116_091.mp4', '706_479.mp4', '476_400.mp4', '755_759.mp4', '615_687.mp4', '273_807.mp4', '236_237.mp4', '440_364.mp4', '346_351.mp4', '272_396.mp4', '466_428.mp4', '003_000.mp4', '294_292.mp4', '129_127.mp4', '531_549.mp4', '828_830.mp4', '357_432.mp4', '958_956.mp4', '165_137.mp4', '096_101.mp4', '359_317.mp4', '879_963.mp4', '403_497.mp4', '435_456.mp4', '667_446.mp4', '285_136.mp4', '875_979.mp4', '120_118.mp4', '217_117.mp4', '570_624.mp4', '674_744.mp4', '252_266.mp4', '624_570.mp4', '952_882.mp4', '264_271.mp4', '378_368.mp4', '941_940.mp4', '381_376.mp4', '322_315.mp4', '866_878.mp4', '337_522.mp4', '037_072.mp4', '740_796.mp4', '404_429.mp4', '979_875.mp4', '342_416.mp4', '137_165.mp4', '260_331.mp4', '682_669.mp4', '565_589.mp4', '710_788.mp4', '504_502.mp4', '786_819.mp4', '629_618.mp4', '561_998.mp4', '589_565.mp4', '471_455.mp4', '675_608.mp4', '401_395.mp4', '261_254.mp4', '829_808.mp4', '729_727.mp4', '494_445.mp4', '020_344.mp4', '131_518.mp4', '470_468.mp4', '717_684.mp4', '591_605.mp4', '105_180.mp4', '330_162.mp4', '712_716.mp4', '059_050.mp4', '645_688.mp4', '560_557.mp4', '287_426.mp4', '093_121.mp4', '121_093.mp4', '122_144.mp4', '648_654.mp4', '871_814.mp4', '877_886.mp4', '509_525.mp4', '563_537.mp4', '940_941.mp4', '535_587.mp4', '076_079.mp4', '630_623.mp4', '368_378.mp4', '227_169.mp4', '280_249.mp4', '409_382.mp4', '967_984.mp4', '739_865.mp4', '231_663.mp4', '469_481.mp4', '673_728.mp4', '176_190.mp4', '318_334.mp4', '992_980.mp4', '425_485.mp4', '527_454.mp4', '756_503.mp4', '543_559.mp4', '754_758.mp4', '237_236.mp4', '282_238.mp4', '518_131.mp4', '312_021.mp4', '622_647.mp4', '270_297.mp4', '959_957.mp4', '631_551.mp4', '906_847.mp4', '149_152.mp4', '935_733.mp4', '186_170.mp4', '392_339.mp4', '608_675.mp4', '758_754.mp4', '745_777.mp4', '873_872.mp4', '954_976.mp4', '275_887.mp4', '600_505.mp4', '427_637.mp4', '102_114.mp4', '062_066.mp4', '774_735.mp4', '305_513.mp4', '281_474.mp4', '265_475.mp4', '950_836.mp4', '483_370.mp4', '885_802.mp4', '150_153.mp4', '464_463.mp4', '501_326.mp4', '587_535.mp4', '793_768.mp4', '976_954.mp4', '374_407.mp4', '820_818.mp4', '931_936.mp4', '016_209.mp4', '951_947.mp4', '804_738.mp4', '961_069.mp4', '269_268.mp4', '056_996.mp4', '544_532.mp4', '868_949.mp4', '324_356.mp4', '251_375.mp4', '782_787.mp4', '546_621.mp4', '685_613.mp4', '233_995.mp4', '323_302.mp4', '428_466.mp4', '869_780.mp4', '524_580.mp4', '747_854.mp4', '973_970.mp4', '859_843.mp4', '886_877.mp4', '033_097.mp4', '571_746.mp4', '054_071.mp4', '621_546.mp4', '642_635.mp4', '317_359.mp4', '245_157.mp4', '307_365.mp4', '024_073.mp4', '775_742.mp4', '053_095.mp4', '399_488.mp4', '138_142.mp4', '878_866.mp4', '678_460.mp4', '210_241.mp4', '100_077.mp4', '638_640.mp4', '184_205.mp4', '234_187.mp4', '148_133.mp4', '752_751.mp4', '042_084.mp4', '00 ...
# File selezionati per il batch 15: ['750_743.mp4', '751_752.mp4', '752_751.mp4', '753_789.mp4', '754_758.mp4', '755_759.mp4', '756_503.mp4', '757_573.mp4', '758_754.mp4', '759_755.mp4', '760_611.mp4', '761_766.mp4', '762_832.mp4', '763_930.mp4', '764_850.mp4', '765_867.mp4', '766_761.mp4', '767_694.mp4', '768_793.mp4', '769_784.mp4', '770_791.mp4', '771_849.mp4', '772_708.mp4', '773_652.mp4', '774_735.mp4', '775_742.mp4', '776_676.mp4', '777_745.mp4', '778_798.mp4', '779_794.mp4', '780_869.mp4', '781_806.mp4', '782_787.mp4', '783_916.mp4', '784_769.mp4', '785_736.mp4', '786_819.mp4', '787_782.mp4', '788_710.mp4', '789_753.mp4', '790_014.mp4', '791_770.mp4', '792_903.mp4', '793_768.mp4', '794_779.mp4', '795_907.mp4', '796_740.mp4', '797_844.mp4', '798_778.mp4', '799_809.mp4']
# Elaborato video: 750_743.mp4, estratti 296 volti
# Elaborato video: 751_752.mp4, estratti 290 volti
# Elaborato video: 752_751.mp4, estratti 331 volti
# Elaborato video: 753_789.mp4, estratti 332 volti
# Elaborato video: 754_758.mp4, estratti 387 volti
# Elaborato video: 755_759.mp4, estratti 337 volti
# Elaborato video: 756_503.mp4, estratti 249 volti
# Elaborato video: 757_573.mp4, estratti 441 volti
# Elaborato video: 758_754.mp4, estratti 371 volti
# Elaborato video: 759_755.mp4, estratti 631 volti
# Elaborato video: 760_611.mp4, estratti 647 volti
# Elaborato video: 761_766.mp4, estratti 342 volti
# Elaborato video: 762_832.mp4, estratti 429 volti
# Elaborato video: 763_930.mp4, estratti 52 volti
# Elaborato video: 764_850.mp4, estratti 680 volti
# Elaborato video: 765_867.mp4, estratti 1091 volti
# Elaborato video: 766_761.mp4, estratti 464 volti
# Elaborato video: 767_694.mp4, estratti 299 volti
# Elaborato video: 768_793.mp4, estratti 330 volti
# Elaborato video: 769_784.mp4, estratti 486 volti
# Elaborato video: 770_791.mp4, estratti 333 volti
# Elaborato video: 771_849.mp4, estratti 322 volti
# Elaborato video: 772_708.mp4, estratti 221 volti
# Elaborato video: 773_652.mp4, estratti 454 volti
# Elaborato video: 774_735.mp4, estratti 313 volti
# Elaborato video: 775_742.mp4, estratti 559 volti
# Elaborato video: 776_676.mp4, estratti 326 volti
# Elaborato video: 777_745.mp4, estratti 325 volti
# Elaborato video: 778_798.mp4, estratti 344 volti
# Elaborato video: 779_794.mp4, estratti 306 volti
# Elaborato video: 780_869.mp4, estratti 333 volti
# Elaborato video: 781_806.mp4, estratti 301 volti
# Elaborato video: 782_787.mp4, estratti 520 volti
# Elaborato video: 783_916.mp4, estratti 416 volti
# Elaborato video: 784_769.mp4, estratti 861 volti
# Elaborato video: 785_736.mp4, estratti 413 volti
# Elaborato video: 786_819.mp4, estratti 610 volti
# Elaborato video: 787_782.mp4, estratti 554 volti
# Elaborato video: 788_710.mp4, estratti 378 volti
# Elaborato video: 789_753.mp4, estratti 588 volti
# Elaborato video: 790_014.mp4, estratti 676 volti
# Elaborato video: 791_770.mp4, estratti 313 volti
# Elaborato video: 792_903.mp4, estratti 383 volti
# Elaborato video: 793_768.mp4, estratti 330 volti
# Elaborato video: 794_779.mp4, estratti 316 volti
# Elaborato video: 795_907.mp4, estratti 403 volti
# Elaborato video: 796_740.mp4, estratti 364 volti
# Elaborato video: 797_844.mp4, estratti 438 volti
# Elaborato video: 798_778.mp4, estratti 328 volti
# Elaborato video: 799_809.mp4, estratti 370 volti
# Elaborazione batch 16 in cartella: videos
# Percorso cartella: FaceSwap/c40/videos
# File nella cartella: ['475_265.mp4', '366_473.mp4', '944_032.mp4', '135_880.mp4', '002_006.mp4', '078_955.mp4', '051_332.mp4', '193_030.mp4', '068_028.mp4', '654_648.mp4', '151_225.mp4', '460_678.mp4', '173_171.mp4', '139_130.mp4', '030_193.mp4', '862_047.mp4', '762_832.mp4', '268_269.mp4', '503_756.mp4', '213_083.mp4', '748_355.mp4', '751_752.mp4', '666_656.mp4', '892_112.mp4', '734_699.mp4', '876_891.mp4', '620_619.mp4', '391_406.mp4', '343_363.mp4', '448_361.mp4', '750_743.mp4', '402_453.mp4', '304_300.mp4', '765_867.mp4', '817_827.mp4', '228_289.mp4', '499_539.mp4', '155_576.mp4', '917_924.mp4', '380_358.mp4', '628_568.mp4', '777_745.mp4', '219_220.mp4', '603_575.mp4', '982_004.mp4', '939_115.mp4', '408_424.mp4', '107_109.mp4', '461_250.mp4', '140_143.mp4', '627_658.mp4', '185_276.mp4', '991_064.mp4', '759_755.mp4', '902_901.mp4', '592_500.mp4', '430_459.mp4', '872_873.mp4', '441_439.mp4', '924_917.mp4', '112_892.mp4', '824_419.mp4', '694_767.mp4', '708_772.mp4', '890_837.mp4', '852_834.mp4', '595_597.mp4', '360_437.mp4', '207_908.mp4', '017_803.mp4', '575_603.mp4', '075_977.mp4', '443_514.mp4', '848_894.mp4', '241_210.mp4', '578_636.mp4', '158_379.mp4', '116_091.mp4', '706_479.mp4', '476_400.mp4', '755_759.mp4', '615_687.mp4', '273_807.mp4', '236_237.mp4', '440_364.mp4', '346_351.mp4', '272_396.mp4', '466_428.mp4', '003_000.mp4', '294_292.mp4', '129_127.mp4', '531_549.mp4', '828_830.mp4', '357_432.mp4', '958_956.mp4', '165_137.mp4', '096_101.mp4', '359_317.mp4', '879_963.mp4', '403_497.mp4', '435_456.mp4', '667_446.mp4', '285_136.mp4', '875_979.mp4', '120_118.mp4', '217_117.mp4', '570_624.mp4', '674_744.mp4', '252_266.mp4', '624_570.mp4', '952_882.mp4', '264_271.mp4', '378_368.mp4', '941_940.mp4', '381_376.mp4', '322_315.mp4', '866_878.mp4', '337_522.mp4', '037_072.mp4', '740_796.mp4', '404_429.mp4', '979_875.mp4', '342_416.mp4', '137_165.mp4', '260_331.mp4', '682_669.mp4', '565_589.mp4', '710_788.mp4', '504_502.mp4', '786_819.mp4', '629_618.mp4', '561_998.mp4', '589_565.mp4', '471_455.mp4', '675_608.mp4', '401_395.mp4', '261_254.mp4', '829_808.mp4', '729_727.mp4', '494_445.mp4', '020_344.mp4', '131_518.mp4', '470_468.mp4', '717_684.mp4', '591_605.mp4', '105_180.mp4', '330_162.mp4', '712_716.mp4', '059_050.mp4', '645_688.mp4', '560_557.mp4', '287_426.mp4', '093_121.mp4', '121_093.mp4', '122_144.mp4', '648_654.mp4', '871_814.mp4', '877_886.mp4', '509_525.mp4', '563_537.mp4', '940_941.mp4', '535_587.mp4', '076_079.mp4', '630_623.mp4', '368_378.mp4', '227_169.mp4', '280_249.mp4', '409_382.mp4', '967_984.mp4', '739_865.mp4', '231_663.mp4', '469_481.mp4', '673_728.mp4', '176_190.mp4', '318_334.mp4', '992_980.mp4', '425_485.mp4', '527_454.mp4', '756_503.mp4', '543_559.mp4', '754_758.mp4', '237_236.mp4', '282_238.mp4', '518_131.mp4', '312_021.mp4', '622_647.mp4', '270_297.mp4', '959_957.mp4', '631_551.mp4', '906_847.mp4', '149_152.mp4', '935_733.mp4', '186_170.mp4', '392_339.mp4', '608_675.mp4', '758_754.mp4', '745_777.mp4', '873_872.mp4', '954_976.mp4', '275_887.mp4', '600_505.mp4', '427_637.mp4', '102_114.mp4', '062_066.mp4', '774_735.mp4', '305_513.mp4', '281_474.mp4', '265_475.mp4', '950_836.mp4', '483_370.mp4', '885_802.mp4', '150_153.mp4', '464_463.mp4', '501_326.mp4', '587_535.mp4', '793_768.mp4', '976_954.mp4', '374_407.mp4', '820_818.mp4', '931_936.mp4', '016_209.mp4', '951_947.mp4', '804_738.mp4', '961_069.mp4', '269_268.mp4', '056_996.mp4', '544_532.mp4', '868_949.mp4', '324_356.mp4', '251_375.mp4', '782_787.mp4', '546_621.mp4', '685_613.mp4', '233_995.mp4', '323_302.mp4', '428_466.mp4', '869_780.mp4', '524_580.mp4', '747_854.mp4', '973_970.mp4', '859_843.mp4', '886_877.mp4', '033_097.mp4', '571_746.mp4', '054_071.mp4', '621_546.mp4', '642_635.mp4', '317_359.mp4', '245_157.mp4', '307_365.mp4', '024_073.mp4', '775_742.mp4', '053_095.mp4', '399_488.mp4', '138_142.mp4', '878_866.mp4', '678_460.mp4', '210_241.mp4', '100_077.mp4', '638_640.mp4', '184_205.mp4', '234_187.mp4', '148_133.mp4', '752_751.mp4', '042_084.mp4', '00 ...
# File selezionati per il batch 16: ['800_840.mp4', '801_855.mp4', '802_885.mp4', '803_017.mp4', '804_738.mp4', '805_011.mp4', '806_781.mp4', '807_273.mp4', '808_829.mp4', '809_799.mp4', '810_838.mp4', '811_920.mp4', '812_821.mp4', '813_700.mp4', '814_871.mp4', '815_730.mp4', '816_649.mp4', '817_827.mp4', '818_820.mp4', '819_786.mp4', '820_818.mp4', '821_812.mp4', '822_244.mp4', '823_584.mp4', '824_419.mp4', '825_074.mp4', '826_833.mp4', '827_817.mp4', '828_830.mp4', '829_808.mp4', '830_828.mp4', '831_508.mp4', '832_762.mp4', '833_826.mp4', '834_852.mp4', '835_651.mp4', '836_950.mp4', '837_890.mp4', '838_810.mp4', '839_864.mp4', '840_800.mp4', '841_639.mp4', '842_714.mp4', '843_859.mp4', '844_797.mp4', '845_846.mp4', '846_845.mp4', '847_906.mp4', '848_894.mp4', '849_771.mp4']
# Elaborato video: 800_840.mp4, estratti 338 volti
# Elaborato video: 801_855.mp4, estratti 899 volti
# Elaborato video: 802_885.mp4, estratti 329 volti
# Elaborato video: 803_017.mp4, estratti 251 volti
# Elaborato video: 804_738.mp4, estratti 377 volti
# Elaborato video: 805_011.mp4, estratti 367 volti
# Elaborato video: 806_781.mp4, estratti 301 volti
# Elaborato video: 807_273.mp4, estratti 322 volti
# Elaborato video: 808_829.mp4, estratti 525 volti
# Elaborato video: 809_799.mp4, estratti 262 volti
# Elaborato video: 810_838.mp4, estratti 559 volti
# Elaborato video: 811_920.mp4, estratti 327 volti
# Elaborato video: 812_821.mp4, estratti 669 volti
# Elaborato video: 813_700.mp4, estratti 356 volti
# Elaborato video: 814_871.mp4, estratti 348 volti
# Elaborato video: 815_730.mp4, estratti 453 volti
# Elaborato video: 816_649.mp4, estratti 413 volti
# Elaborato video: 817_827.mp4, estratti 314 volti
# Elaborato video: 818_820.mp4, estratti 514 volti
# Elaborato video: 819_786.mp4, estratti 520 volti
# Elaborato video: 820_818.mp4, estratti 435 volti
# Elaborato video: 821_812.mp4, estratti 405 volti
# Elaborato video: 822_244.mp4, estratti 297 volti
# Elaborato video: 823_584.mp4, estratti 479 volti
# Elaborato video: 824_419.mp4, estratti 919 volti
# Elaborato video: 825_074.mp4, estratti 345 volti
# Elaborato video: 826_833.mp4, estratti 188 volti
# Elaborato video: 827_817.mp4, estratti 311 volti
# Elaborato video: 828_830.mp4, estratti 319 volti
# Elaborato video: 829_808.mp4, estratti 637 volti
# Elaborato video: 830_828.mp4, estratti 778 volti
# Elaborato video: 831_508.mp4, estratti 317 volti
# Elaborato video: 832_762.mp4, estratti 536 volti
# Elaborato video: 833_826.mp4, estratti 356 volti
# Elaborato video: 834_852.mp4, estratti 303 volti
# Elaborato video: 835_651.mp4, estratti 382 volti
# Elaborato video: 836_950.mp4, estratti 337 volti
# Elaborato video: 837_890.mp4, estratti 347 volti
# Elaborato video: 838_810.mp4, estratti 456 volti
# Elaborato video: 839_864.mp4, estratti 326 volti
# Elaborato video: 840_800.mp4, estratti 338 volti
# Elaborato video: 841_639.mp4, estratti 519 volti
# Elaborato video: 842_714.mp4, estratti 14 volti
# Elaborato video: 843_859.mp4, estratti 288 volti
# Elaborato video: 844_797.mp4, estratti 434 volti
# Elaborato video: 845_846.mp4, estratti 353 volti
# Elaborato video: 846_845.mp4, estratti 353 volti
# Elaborato video: 847_906.mp4, estratti 300 volti
# Elaborato video: 848_894.mp4, estratti 331 volti
# Elaborato video: 849_771.mp4, estratti 322 volti
# Elaborazione batch 17 in cartella: videos
# Percorso cartella: FaceSwap/c40/videos
# File nella cartella: ['475_265.mp4', '366_473.mp4', '944_032.mp4', '135_880.mp4', '002_006.mp4', '078_955.mp4', '051_332.mp4', '193_030.mp4', '068_028.mp4', '654_648.mp4', '151_225.mp4', '460_678.mp4', '173_171.mp4', '139_130.mp4', '030_193.mp4', '862_047.mp4', '762_832.mp4', '268_269.mp4', '503_756.mp4', '213_083.mp4', '748_355.mp4', '751_752.mp4', '666_656.mp4', '892_112.mp4', '734_699.mp4', '876_891.mp4', '620_619.mp4', '391_406.mp4', '343_363.mp4', '448_361.mp4', '750_743.mp4', '402_453.mp4', '304_300.mp4', '765_867.mp4', '817_827.mp4', '228_289.mp4', '499_539.mp4', '155_576.mp4', '917_924.mp4', '380_358.mp4', '628_568.mp4', '777_745.mp4', '219_220.mp4', '603_575.mp4', '982_004.mp4', '939_115.mp4', '408_424.mp4', '107_109.mp4', '461_250.mp4', '140_143.mp4', '627_658.mp4', '185_276.mp4', '991_064.mp4', '759_755.mp4', '902_901.mp4', '592_500.mp4', '430_459.mp4', '872_873.mp4', '441_439.mp4', '924_917.mp4', '112_892.mp4', '824_419.mp4', '694_767.mp4', '708_772.mp4', '890_837.mp4', '852_834.mp4', '595_597.mp4', '360_437.mp4', '207_908.mp4', '017_803.mp4', '575_603.mp4', '075_977.mp4', '443_514.mp4', '848_894.mp4', '241_210.mp4', '578_636.mp4', '158_379.mp4', '116_091.mp4', '706_479.mp4', '476_400.mp4', '755_759.mp4', '615_687.mp4', '273_807.mp4', '236_237.mp4', '440_364.mp4', '346_351.mp4', '272_396.mp4', '466_428.mp4', '003_000.mp4', '294_292.mp4', '129_127.mp4', '531_549.mp4', '828_830.mp4', '357_432.mp4', '958_956.mp4', '165_137.mp4', '096_101.mp4', '359_317.mp4', '879_963.mp4', '403_497.mp4', '435_456.mp4', '667_446.mp4', '285_136.mp4', '875_979.mp4', '120_118.mp4', '217_117.mp4', '570_624.mp4', '674_744.mp4', '252_266.mp4', '624_570.mp4', '952_882.mp4', '264_271.mp4', '378_368.mp4', '941_940.mp4', '381_376.mp4', '322_315.mp4', '866_878.mp4', '337_522.mp4', '037_072.mp4', '740_796.mp4', '404_429.mp4', '979_875.mp4', '342_416.mp4', '137_165.mp4', '260_331.mp4', '682_669.mp4', '565_589.mp4', '710_788.mp4', '504_502.mp4', '786_819.mp4', '629_618.mp4', '561_998.mp4', '589_565.mp4', '471_455.mp4', '675_608.mp4', '401_395.mp4', '261_254.mp4', '829_808.mp4', '729_727.mp4', '494_445.mp4', '020_344.mp4', '131_518.mp4', '470_468.mp4', '717_684.mp4', '591_605.mp4', '105_180.mp4', '330_162.mp4', '712_716.mp4', '059_050.mp4', '645_688.mp4', '560_557.mp4', '287_426.mp4', '093_121.mp4', '121_093.mp4', '122_144.mp4', '648_654.mp4', '871_814.mp4', '877_886.mp4', '509_525.mp4', '563_537.mp4', '940_941.mp4', '535_587.mp4', '076_079.mp4', '630_623.mp4', '368_378.mp4', '227_169.mp4', '280_249.mp4', '409_382.mp4', '967_984.mp4', '739_865.mp4', '231_663.mp4', '469_481.mp4', '673_728.mp4', '176_190.mp4', '318_334.mp4', '992_980.mp4', '425_485.mp4', '527_454.mp4', '756_503.mp4', '543_559.mp4', '754_758.mp4', '237_236.mp4', '282_238.mp4', '518_131.mp4', '312_021.mp4', '622_647.mp4', '270_297.mp4', '959_957.mp4', '631_551.mp4', '906_847.mp4', '149_152.mp4', '935_733.mp4', '186_170.mp4', '392_339.mp4', '608_675.mp4', '758_754.mp4', '745_777.mp4', '873_872.mp4', '954_976.mp4', '275_887.mp4', '600_505.mp4', '427_637.mp4', '102_114.mp4', '062_066.mp4', '774_735.mp4', '305_513.mp4', '281_474.mp4', '265_475.mp4', '950_836.mp4', '483_370.mp4', '885_802.mp4', '150_153.mp4', '464_463.mp4', '501_326.mp4', '587_535.mp4', '793_768.mp4', '976_954.mp4', '374_407.mp4', '820_818.mp4', '931_936.mp4', '016_209.mp4', '951_947.mp4', '804_738.mp4', '961_069.mp4', '269_268.mp4', '056_996.mp4', '544_532.mp4', '868_949.mp4', '324_356.mp4', '251_375.mp4', '782_787.mp4', '546_621.mp4', '685_613.mp4', '233_995.mp4', '323_302.mp4', '428_466.mp4', '869_780.mp4', '524_580.mp4', '747_854.mp4', '973_970.mp4', '859_843.mp4', '886_877.mp4', '033_097.mp4', '571_746.mp4', '054_071.mp4', '621_546.mp4', '642_635.mp4', '317_359.mp4', '245_157.mp4', '307_365.mp4', '024_073.mp4', '775_742.mp4', '053_095.mp4', '399_488.mp4', '138_142.mp4', '878_866.mp4', '678_460.mp4', '210_241.mp4', '100_077.mp4', '638_640.mp4', '184_205.mp4', '234_187.mp4', '148_133.mp4', '752_751.mp4', '042_084.mp4', '00 ...
# File selezionati per il batch 17: ['850_764.mp4', '851_552.mp4', '852_834.mp4', '853_863.mp4', '854_747.mp4', '855_801.mp4', '856_881.mp4', '857_909.mp4', '858_861.mp4', '859_843.mp4', '860_905.mp4', '861_858.mp4', '862_047.mp4', '863_853.mp4', '864_839.mp4', '865_739.mp4', '866_878.mp4', '867_765.mp4', '868_949.mp4', '869_780.mp4', '870_001.mp4', '871_814.mp4', '872_873.mp4', '873_872.mp4', '874_291.mp4', '875_979.mp4', '876_891.mp4', '877_886.mp4', '878_866.mp4', '879_963.mp4', '880_135.mp4', '881_856.mp4', '882_952.mp4', '883_013.mp4', '884_968.mp4', '885_802.mp4', '886_877.mp4', '887_275.mp4', '888_937.mp4', '889_045.mp4', '890_837.mp4', '891_876.mp4', '892_112.mp4', '893_913.mp4', '894_848.mp4', '895_915.mp4', '896_128.mp4', '897_969.mp4', '898_922.mp4', '899_914.mp4']
# Elaborato video: 850_764.mp4, estratti 341 volti
# Elaborato video: 851_552.mp4, estratti 208 volti
# Elaborato video: 852_834.mp4, estratti 302 volti
# Elaborato video: 853_863.mp4, estratti 487 volti
# Elaborato video: 854_747.mp4, estratti 189 volti
# Elaborato video: 855_801.mp4, estratti 480 volti
# Elaborato video: 856_881.mp4, estratti 638 volti
# Elaborato video: 857_909.mp4, estratti 371 volti
# Elaborato video: 858_861.mp4, estratti 483 volti
# Elaborato video: 859_843.mp4, estratti 315 volti
# Elaborato video: 860_905.mp4, estratti 384 volti
# Elaborato video: 861_858.mp4, estratti 495 volti
# Elaborato video: 862_047.mp4, estratti 319 volti
# Elaborato video: 863_853.mp4, estratti 540 volti
# Elaborato video: 864_839.mp4, estratti 326 volti
# Elaborato video: 865_739.mp4, estratti 324 volti
# Elaborato video: 866_878.mp4, estratti 504 volti
# Elaborato video: 867_765.mp4, estratti 388 volti
# Elaborato video: 868_949.mp4, estratti 431 volti
# Elaborato video: 869_780.mp4, estratti 853 volti
# Elaborato video: 870_001.mp4, estratti 460 volti
# Elaborato video: 871_814.mp4, estratti 393 volti
# Elaborato video: 872_873.mp4, estratti 549 volti
# Elaborato video: 873_872.mp4, estratti 1426 volti
# Elaborato video: 874_291.mp4, estratti 330 volti
# Elaborato video: 875_979.mp4, estratti 352 volti
# Elaborato video: 876_891.mp4, estratti 273 volti
# Elaborato video: 877_886.mp4, estratti 506 volti
# Elaborato video: 878_866.mp4, estratti 493 volti
# Elaborato video: 879_963.mp4, estratti 684 volti
# Elaborato video: 880_135.mp4, estratti 3 volti
# Elaborato video: 881_856.mp4, estratti 638 volti
# Elaborato video: 882_952.mp4, estratti 347 volti
# Elaborato video: 883_013.mp4, estratti 332 volti
# Elaborato video: 884_968.mp4, estratti 300 volti
# Elaborato video: 885_802.mp4, estratti 329 volti
# Elaborato video: 886_877.mp4, estratti 525 volti
# Elaborato video: 887_275.mp4, estratti 238 volti
# Elaborato video: 888_937.mp4, estratti 308 volti
# Elaborato video: 889_045.mp4, estratti 315 volti
# Elaborato video: 890_837.mp4, estratti 341 volti
# Elaborato video: 891_876.mp4, estratti 175 volti
# Elaborato video: 892_112.mp4, estratti 323 volti
# Elaborato video: 893_913.mp4, estratti 505 volti
# Elaborato video: 894_848.mp4, estratti 307 volti
# Elaborato video: 895_915.mp4, estratti 294 volti
# Elaborato video: 896_128.mp4, estratti 531 volti
# Elaborato video: 897_969.mp4, estratti 388 volti
# Elaborato video: 898_922.mp4, estratti 349 volti
# Elaborato video: 899_914.mp4, estratti 312 volti
# Elaborazione batch 18 in cartella: videos
# Percorso cartella: FaceSwap/c40/videos
# File nella cartella: ['475_265.mp4', '366_473.mp4', '944_032.mp4', '135_880.mp4', '002_006.mp4', '078_955.mp4', '051_332.mp4', '193_030.mp4', '068_028.mp4', '654_648.mp4', '151_225.mp4', '460_678.mp4', '173_171.mp4', '139_130.mp4', '030_193.mp4', '862_047.mp4', '762_832.mp4', '268_269.mp4', '503_756.mp4', '213_083.mp4', '748_355.mp4', '751_752.mp4', '666_656.mp4', '892_112.mp4', '734_699.mp4', '876_891.mp4', '620_619.mp4', '391_406.mp4', '343_363.mp4', '448_361.mp4', '750_743.mp4', '402_453.mp4', '304_300.mp4', '765_867.mp4', '817_827.mp4', '228_289.mp4', '499_539.mp4', '155_576.mp4', '917_924.mp4', '380_358.mp4', '628_568.mp4', '777_745.mp4', '219_220.mp4', '603_575.mp4', '982_004.mp4', '939_115.mp4', '408_424.mp4', '107_109.mp4', '461_250.mp4', '140_143.mp4', '627_658.mp4', '185_276.mp4', '991_064.mp4', '759_755.mp4', '902_901.mp4', '592_500.mp4', '430_459.mp4', '872_873.mp4', '441_439.mp4', '924_917.mp4', '112_892.mp4', '824_419.mp4', '694_767.mp4', '708_772.mp4', '890_837.mp4', '852_834.mp4', '595_597.mp4', '360_437.mp4', '207_908.mp4', '017_803.mp4', '575_603.mp4', '075_977.mp4', '443_514.mp4', '848_894.mp4', '241_210.mp4', '578_636.mp4', '158_379.mp4', '116_091.mp4', '706_479.mp4', '476_400.mp4', '755_759.mp4', '615_687.mp4', '273_807.mp4', '236_237.mp4', '440_364.mp4', '346_351.mp4', '272_396.mp4', '466_428.mp4', '003_000.mp4', '294_292.mp4', '129_127.mp4', '531_549.mp4', '828_830.mp4', '357_432.mp4', '958_956.mp4', '165_137.mp4', '096_101.mp4', '359_317.mp4', '879_963.mp4', '403_497.mp4', '435_456.mp4', '667_446.mp4', '285_136.mp4', '875_979.mp4', '120_118.mp4', '217_117.mp4', '570_624.mp4', '674_744.mp4', '252_266.mp4', '624_570.mp4', '952_882.mp4', '264_271.mp4', '378_368.mp4', '941_940.mp4', '381_376.mp4', '322_315.mp4', '866_878.mp4', '337_522.mp4', '037_072.mp4', '740_796.mp4', '404_429.mp4', '979_875.mp4', '342_416.mp4', '137_165.mp4', '260_331.mp4', '682_669.mp4', '565_589.mp4', '710_788.mp4', '504_502.mp4', '786_819.mp4', '629_618.mp4', '561_998.mp4', '589_565.mp4', '471_455.mp4', '675_608.mp4', '401_395.mp4', '261_254.mp4', '829_808.mp4', '729_727.mp4', '494_445.mp4', '020_344.mp4', '131_518.mp4', '470_468.mp4', '717_684.mp4', '591_605.mp4', '105_180.mp4', '330_162.mp4', '712_716.mp4', '059_050.mp4', '645_688.mp4', '560_557.mp4', '287_426.mp4', '093_121.mp4', '121_093.mp4', '122_144.mp4', '648_654.mp4', '871_814.mp4', '877_886.mp4', '509_525.mp4', '563_537.mp4', '940_941.mp4', '535_587.mp4', '076_079.mp4', '630_623.mp4', '368_378.mp4', '227_169.mp4', '280_249.mp4', '409_382.mp4', '967_984.mp4', '739_865.mp4', '231_663.mp4', '469_481.mp4', '673_728.mp4', '176_190.mp4', '318_334.mp4', '992_980.mp4', '425_485.mp4', '527_454.mp4', '756_503.mp4', '543_559.mp4', '754_758.mp4', '237_236.mp4', '282_238.mp4', '518_131.mp4', '312_021.mp4', '622_647.mp4', '270_297.mp4', '959_957.mp4', '631_551.mp4', '906_847.mp4', '149_152.mp4', '935_733.mp4', '186_170.mp4', '392_339.mp4', '608_675.mp4', '758_754.mp4', '745_777.mp4', '873_872.mp4', '954_976.mp4', '275_887.mp4', '600_505.mp4', '427_637.mp4', '102_114.mp4', '062_066.mp4', '774_735.mp4', '305_513.mp4', '281_474.mp4', '265_475.mp4', '950_836.mp4', '483_370.mp4', '885_802.mp4', '150_153.mp4', '464_463.mp4', '501_326.mp4', '587_535.mp4', '793_768.mp4', '976_954.mp4', '374_407.mp4', '820_818.mp4', '931_936.mp4', '016_209.mp4', '951_947.mp4', '804_738.mp4', '961_069.mp4', '269_268.mp4', '056_996.mp4', '544_532.mp4', '868_949.mp4', '324_356.mp4', '251_375.mp4', '782_787.mp4', '546_621.mp4', '685_613.mp4', '233_995.mp4', '323_302.mp4', '428_466.mp4', '869_780.mp4', '524_580.mp4', '747_854.mp4', '973_970.mp4', '859_843.mp4', '886_877.mp4', '033_097.mp4', '571_746.mp4', '054_071.mp4', '621_546.mp4', '642_635.mp4', '317_359.mp4', '245_157.mp4', '307_365.mp4', '024_073.mp4', '775_742.mp4', '053_095.mp4', '399_488.mp4', '138_142.mp4', '878_866.mp4', '678_460.mp4', '210_241.mp4', '100_077.mp4', '638_640.mp4', '184_205.mp4', '234_187.mp4', '148_133.mp4', '752_751.mp4', '042_084.mp4', '00 ...
# File selezionati per il batch 18: ['900_926.mp4', '901_902.mp4', '902_901.mp4', '903_792.mp4', '904_046.mp4', '905_860.mp4', '906_847.mp4', '907_795.mp4', '908_207.mp4', '909_857.mp4', '910_911.mp4', '911_910.mp4', '912_927.mp4', '913_893.mp4', '914_899.mp4', '915_895.mp4', '916_783.mp4', '917_924.mp4', '918_934.mp4', '919_015.mp4', '920_811.mp4', '921_569.mp4', '922_898.mp4', '923_023.mp4', '924_917.mp4', '925_933.mp4', '926_900.mp4', '927_912.mp4', '928_160.mp4', '929_962.mp4', '930_763.mp4', '931_936.mp4', '932_384.mp4', '933_925.mp4', '934_918.mp4', '935_733.mp4', '936_931.mp4', '937_888.mp4', '938_987.mp4', '939_115.mp4', '940_941.mp4', '941_940.mp4', '942_943.mp4', '943_942.mp4', '944_032.mp4', '945_044.mp4', '946_049.mp4', '947_951.mp4', '948_965.mp4', '949_868.mp4']
# Elaborato video: 900_926.mp4, estratti 334 volti
# Elaborato video: 901_902.mp4, estratti 293 volti
# Elaborato video: 902_901.mp4, estratti 409 volti
# Elaborato video: 903_792.mp4, estratti 385 volti
# Elaborato video: 904_046.mp4, estratti 359 volti
# Elaborato video: 905_860.mp4, estratti 203 volti
# Elaborato video: 906_847.mp4, estratti 302 volti
# Elaborato video: 907_795.mp4, estratti 832 volti
# Elaborato video: 908_207.mp4, estratti 348 volti
# Elaborato video: 909_857.mp4, estratti 637 volti
# Elaborato video: 910_911.mp4, estratti 293 volti
# Elaborato video: 911_910.mp4, estratti 486 volti
# Elaborato video: 912_927.mp4, estratti 210 volti
# Elaborato video: 913_893.mp4, estratti 361 volti
# Elaborato video: 914_899.mp4, estratti 417 volti
# Elaborato video: 915_895.mp4, estratti 231 volti
# Elaborato video: 916_783.mp4, estratti 311 volti
# Elaborato video: 917_924.mp4, estratti 455 volti
# Elaborato video: 918_934.mp4, estratti 377 volti
# Elaborato video: 919_015.mp4, estratti 437 volti
# Elaborato video: 920_811.mp4, estratti 345 volti
# Elaborato video: 921_569.mp4, estratti 98 volti
# Elaborato video: 922_898.mp4, estratti 350 volti
# Elaborato video: 923_023.mp4, estratti 554 volti
# Elaborato video: 924_917.mp4, estratti 449 volti
# Elaborato video: 925_933.mp4, estratti 360 volti
# Elaborato video: 926_900.mp4, estratti 337 volti
# Elaborato video: 927_912.mp4, estratti 652 volti
# Elaborato video: 928_160.mp4, estratti 374 volti
# Elaborato video: 929_962.mp4, estratti 465 volti
# Elaborato video: 930_763.mp4, estratti 635 volti
# Elaborato video: 931_936.mp4, estratti 308 volti
# Elaborato video: 932_384.mp4, estratti 7 volti
# Elaborato video: 933_925.mp4, estratti 356 volti
# Elaborato video: 934_918.mp4, estratti 566 volti
# Elaborato video: 935_733.mp4, estratti 557 volti
# Elaborato video: 936_931.mp4, estratti 297 volti
# Elaborato video: 937_888.mp4, estratti 302 volti
# Elaborato video: 938_987.mp4, estratti 369 volti
# Elaborato video: 939_115.mp4, estratti 325 volti
# Elaborato video: 940_941.mp4, estratti 310 volti
# Elaborato video: 941_940.mp4, estratti 309 volti
# Elaborato video: 942_943.mp4, estratti 520 volti
# Elaborato video: 943_942.mp4, estratti 221 volti
# Elaborato video: 944_032.mp4, estratti 250 volti
# Elaborato video: 945_044.mp4, estratti 350 volti
# Elaborato video: 946_049.mp4, estratti 353 volti
# Elaborato video: 947_951.mp4, estratti 667 volti
# Elaborato video: 948_965.mp4, estratti 335 volti
# Elaborato video: 949_868.mp4, estratti 431 volti
# Elaborazione batch 19 in cartella: videos
# Percorso cartella: FaceSwap/c40/videos
# File nella cartella: ['475_265.mp4', '366_473.mp4', '944_032.mp4', '135_880.mp4', '002_006.mp4', '078_955.mp4', '051_332.mp4', '193_030.mp4', '068_028.mp4', '654_648.mp4', '151_225.mp4', '460_678.mp4', '173_171.mp4', '139_130.mp4', '030_193.mp4', '862_047.mp4', '762_832.mp4', '268_269.mp4', '503_756.mp4', '213_083.mp4', '748_355.mp4', '751_752.mp4', '666_656.mp4', '892_112.mp4', '734_699.mp4', '876_891.mp4', '620_619.mp4', '391_406.mp4', '343_363.mp4', '448_361.mp4', '750_743.mp4', '402_453.mp4', '304_300.mp4', '765_867.mp4', '817_827.mp4', '228_289.mp4', '499_539.mp4', '155_576.mp4', '917_924.mp4', '380_358.mp4', '628_568.mp4', '777_745.mp4', '219_220.mp4', '603_575.mp4', '982_004.mp4', '939_115.mp4', '408_424.mp4', '107_109.mp4', '461_250.mp4', '140_143.mp4', '627_658.mp4', '185_276.mp4', '991_064.mp4', '759_755.mp4', '902_901.mp4', '592_500.mp4', '430_459.mp4', '872_873.mp4', '441_439.mp4', '924_917.mp4', '112_892.mp4', '824_419.mp4', '694_767.mp4', '708_772.mp4', '890_837.mp4', '852_834.mp4', '595_597.mp4', '360_437.mp4', '207_908.mp4', '017_803.mp4', '575_603.mp4', '075_977.mp4', '443_514.mp4', '848_894.mp4', '241_210.mp4', '578_636.mp4', '158_379.mp4', '116_091.mp4', '706_479.mp4', '476_400.mp4', '755_759.mp4', '615_687.mp4', '273_807.mp4', '236_237.mp4', '440_364.mp4', '346_351.mp4', '272_396.mp4', '466_428.mp4', '003_000.mp4', '294_292.mp4', '129_127.mp4', '531_549.mp4', '828_830.mp4', '357_432.mp4', '958_956.mp4', '165_137.mp4', '096_101.mp4', '359_317.mp4', '879_963.mp4', '403_497.mp4', '435_456.mp4', '667_446.mp4', '285_136.mp4', '875_979.mp4', '120_118.mp4', '217_117.mp4', '570_624.mp4', '674_744.mp4', '252_266.mp4', '624_570.mp4', '952_882.mp4', '264_271.mp4', '378_368.mp4', '941_940.mp4', '381_376.mp4', '322_315.mp4', '866_878.mp4', '337_522.mp4', '037_072.mp4', '740_796.mp4', '404_429.mp4', '979_875.mp4', '342_416.mp4', '137_165.mp4', '260_331.mp4', '682_669.mp4', '565_589.mp4', '710_788.mp4', '504_502.mp4', '786_819.mp4', '629_618.mp4', '561_998.mp4', '589_565.mp4', '471_455.mp4', '675_608.mp4', '401_395.mp4', '261_254.mp4', '829_808.mp4', '729_727.mp4', '494_445.mp4', '020_344.mp4', '131_518.mp4', '470_468.mp4', '717_684.mp4', '591_605.mp4', '105_180.mp4', '330_162.mp4', '712_716.mp4', '059_050.mp4', '645_688.mp4', '560_557.mp4', '287_426.mp4', '093_121.mp4', '121_093.mp4', '122_144.mp4', '648_654.mp4', '871_814.mp4', '877_886.mp4', '509_525.mp4', '563_537.mp4', '940_941.mp4', '535_587.mp4', '076_079.mp4', '630_623.mp4', '368_378.mp4', '227_169.mp4', '280_249.mp4', '409_382.mp4', '967_984.mp4', '739_865.mp4', '231_663.mp4', '469_481.mp4', '673_728.mp4', '176_190.mp4', '318_334.mp4', '992_980.mp4', '425_485.mp4', '527_454.mp4', '756_503.mp4', '543_559.mp4', '754_758.mp4', '237_236.mp4', '282_238.mp4', '518_131.mp4', '312_021.mp4', '622_647.mp4', '270_297.mp4', '959_957.mp4', '631_551.mp4', '906_847.mp4', '149_152.mp4', '935_733.mp4', '186_170.mp4', '392_339.mp4', '608_675.mp4', '758_754.mp4', '745_777.mp4', '873_872.mp4', '954_976.mp4', '275_887.mp4', '600_505.mp4', '427_637.mp4', '102_114.mp4', '062_066.mp4', '774_735.mp4', '305_513.mp4', '281_474.mp4', '265_475.mp4', '950_836.mp4', '483_370.mp4', '885_802.mp4', '150_153.mp4', '464_463.mp4', '501_326.mp4', '587_535.mp4', '793_768.mp4', '976_954.mp4', '374_407.mp4', '820_818.mp4', '931_936.mp4', '016_209.mp4', '951_947.mp4', '804_738.mp4', '961_069.mp4', '269_268.mp4', '056_996.mp4', '544_532.mp4', '868_949.mp4', '324_356.mp4', '251_375.mp4', '782_787.mp4', '546_621.mp4', '685_613.mp4', '233_995.mp4', '323_302.mp4', '428_466.mp4', '869_780.mp4', '524_580.mp4', '747_854.mp4', '973_970.mp4', '859_843.mp4', '886_877.mp4', '033_097.mp4', '571_746.mp4', '054_071.mp4', '621_546.mp4', '642_635.mp4', '317_359.mp4', '245_157.mp4', '307_365.mp4', '024_073.mp4', '775_742.mp4', '053_095.mp4', '399_488.mp4', '138_142.mp4', '878_866.mp4', '678_460.mp4', '210_241.mp4', '100_077.mp4', '638_640.mp4', '184_205.mp4', '234_187.mp4', '148_133.mp4', '752_751.mp4', '042_084.mp4', '00 ...
# File selezionati per il batch 19: ['950_836.mp4', '951_947.mp4', '952_882.mp4', '953_974.mp4', '954_976.mp4', '955_078.mp4', '956_958.mp4', '957_959.mp4', '958_956.mp4', '959_957.mp4', '960_999.mp4', '961_069.mp4', '962_929.mp4', '963_879.mp4', '964_174.mp4', '965_948.mp4', '966_988.mp4', '967_984.mp4', '968_884.mp4', '969_897.mp4', '970_973.mp4', '971_564.mp4', '972_718.mp4', '973_970.mp4', '974_953.mp4', '975_978.mp4', '976_954.mp4', '977_075.mp4', '978_975.mp4', '979_875.mp4', '980_992.mp4', '981_985.mp4', '982_004.mp4', '983_113.mp4', '984_967.mp4', '985_981.mp4', '986_994.mp4', '987_938.mp4', '988_966.mp4', '989_993.mp4', '990_008.mp4', '991_064.mp4', '992_980.mp4', '993_989.mp4', '994_986.mp4', '995_233.mp4', '996_056.mp4', '997_040.mp4', '998_561.mp4', '999_960.mp4']
# Elaborato video: 950_836.mp4, estratti 350 volti
# Elaborato video: 951_947.mp4, estratti 665 volti
# Elaborato video: 952_882.mp4, estratti 335 volti
# Elaborato video: 953_974.mp4, estratti 327 volti
# Elaborato video: 954_976.mp4, estratti 329 volti
# Elaborato video: 955_078.mp4, estratti 524 volti
# Elaborato video: 956_958.mp4, estratti 392 volti
# Elaborato video: 957_959.mp4, estratti 409 volti
# Elaborato video: 958_956.mp4, estratti 392 volti

# %%
# # Extraction for real video
# for video_file in os.listdir(REAL_VIDEOS_PATH):
#     video_path = os.path.join(REAL_VIDEOS_PATH, video_file)

#     # Call extract_faces_from_video to process the video and extract frames
#     faces, labels = extract_faces_from_video(video_path, LABELS["REAL"], cv2.CascadeClassifier(cascade_path))

#     # Now you have the faces and labels for this specific video
#     print(f"Processed video: {video_file}, extracted {len(faces)} faces")
